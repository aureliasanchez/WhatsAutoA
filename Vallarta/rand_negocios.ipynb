# %% [markdown]
# # **ASIGNAR MENSAJES DE MANERA ALEATORIA**

# %%
import pandas as pd
import random

# %% [markdown]
# ## Y

# %%
# Datos proporcionados
numeros = [
#"3141014948", "3141096298", "3141201187", "3141442114", "3143383254", "3171051914", "3191000168", "3221033347", "3221050120", "3221206608", "3221207516", "3221280621", "3221306055", "3221324529", "3221328748", "3221344887", "3221356815", "3221428411", "3221485991", "3221487342", "3221526146", "3221681790", "3221710120", "3221712774", "3221800075", "3221814408", "3221826768", "3221905851", "3221919730", "3221926080", "3221987297", "3221997975", "3222007651", "3222053575", "3222165058", "3222311641", "3222715955", "3224291363", "3227799982", "3231003128", "3231009565", "3231014237", "3231042322", "3231050466", "3231059153", "3231065784", "3231067733", "3231076749", "3231087742", "3231127344"
"3531013395", "3531017970", "3531028543", "3531035974", "3531036254", "3531052080", "3531056464", "3531073822", "3531084144", "3531084875", "3531088394", "3531089988", "3531100094", "3531100932", "3531240411", "3531264676", "3531424184", "3531471221", "3535351033", "3535397544", "3111135542", "3111227232", "3111501657", "3112017704", "3112304001", "3112463535", "3118478340", "3121007173", "3121022065", "3121061338", "3121071671", "3121094334", "3121143879", "3121187356", "3121203934", "3121217086", "3121269731", "3121308020", "3121316123", "3121316821", "3121321517", "3121321896", "3121343305", "3121375673", "3121381256", "3121387943", "3121393478", "3121399592", "3121428580", "3121435565", "3121451228", "3121459913", "3121483855", "3121498284", "3121525507", "3121553334", "3121568667", "3121572352", "3121623683", "3121632429", "3121653494", "3121687245", "3121943747", "3121948677", "3121982565", "3122102100", "3122315058", "3122425519", "3122437906", "3122564434", "3123008712", "3123008846", "3123092449", "3123172364", "3123195570"
]

# Mensajes con rutas de imágenes
mensajes = [
    {
        "mensaje": """🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perder el EXPO del SUMMIT TURÍSTICO INTERNACIONAL! 🌎✨\n\n📆 27-28 de junio\n📍 Centro Internacional de Convenciones, Puerto Vallarta\nhttps://maps.app.goo.gl/ZARoUF5DKiU1hLr29\n\nConéctate con expertos y descubre lo último en turismo e inversión inmobiliaria en México. 🏝️🏢\n\n📲 Más info: 56 1858 7276 / 32 2596 0129""",
        "imagen": r"C:\Users\4to Creativo\OneDrive\Desktop\WhatsAutoA\Images\summita.png"
    }
]

# %%
# Asignar un mensaje aleatorio a cada número
asignaciones = []
random.seed(42)  # Para reproducibilidad

for numero in numeros:
    asignacion = random.choice(mensajes)
    asignaciones.append({
        "Movil": numero,
        "Mensaje": asignacion["mensaje"].replace("\n", "\n"),
        "Imagen": asignacion["imagen"]
    })

# Convertir a DataFrame de pandas
df = pd.DataFrame(asignaciones)
df
# Out:
#          Movil                                            Mensaje  \
# 0   3531013395  🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perd...
# 1   3531017970  🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perd...
# 2   3531028543  🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perd...
# 3   3531035974  🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perd...
# 4   3531036254  🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perd...
# ..         ...                                                ...
# 70  3123008712  🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perd...
# 71  3123008846  🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perd...
# 72  3123092449  🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perd...
# 73  3123172364  🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perd...
# 74  3123195570  🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perd...
#
#                                                Imagen
# 0   C:\Users\4to Creativo\OneDrive\Desktop\WhatsAu...
# 1   C:\Users\4to Creativo\OneDrive\Desktop\WhatsAu...
# ...

# %% [markdown]
# ### Exportar

# %%
# Exportar a un archivo Excel
df.to_csv("negocios_Y.csv", index=False)

# %% [markdown]
# ## A

# %%
# Datos proporcionados
numeros = [
#"3112480487", "3112481033", "3112481335", "3112489208", "3112502561", "3112507624", "3112532477", "3112600653", "3112601304", "3112601365", "3112629929", "3112631691", "3112637937", "3112646957", "3112648479", "3112664830", "3112665025", "3112666169", "3112671211", "3112696843", "3112697278", "3112834759", "3112858211", "3112927010", "3113390655", "3117400922", "3117402952", "3117434095", "3117439583", "3118475532", "3118475636", "3118477102", "3118478190", "3118479269", "3118479759", "3118513411", "3118764555", "3118768554", "3118769256", "3118773475", "3118777167", "3118907454", "3119106877", "3121014126", "3121133096", "3121420274", "3121552887", "3121574141", "3121946751", "3123181177"
"3231134945", "3231179415", "3231210929", "3231212470", "3231215393", "3231219708", "3231224786", "3231226187", "3231313621", "3232820779", "3232823780", "3237299836", "3241008226", "3241009610", "3241037615", "3241044081", "3241050463", "3241061614", "3241080235", "3241088057", "3241121496", "3271028151", "3271030249", "3271032762", "3271036163", "3271042680", "3271083611", "3271089285", "3271114298", "3279789280", "3312354742", "3312917196", "3314175868", "3314207946", "3315667060", "3316990147", "3318938757", "3331573886", "3331585699", "3338142640", "3338157056", "3338227583", "3511000002", "3511093289", "3511186044", "3511191005", "3511212230", "3511248160", "3511279150", "3511287325", "3511324913", "3511353191", "3511355776", "3511451635", "3511494709", "3511630604", "3511864733", "3511906522", "3515092917", "3515098963", "3515125354", "3515130393", "3515178732", "3515196619", "3517471062", "3521004700", "3521036512", "3521039105", "3521065993", "3521071017", "3521104383", "3521128086", "3521205475", "3531001517", "3531008840"
]

# Mensajes con rutas de imágenes
mensajes = [
    {
        "mensaje": """🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perder el EXPO del SUMMIT TURÍSTICO INTERNACIONAL! 🌎✨\n\n📆 27-28 de junio\n📍 Centro Internacional de Convenciones, Puerto Vallarta\nhttps://maps.app.goo.gl/ZARoUF5DKiU1hLr29\n\nConéctate con expertos y descubre lo último en turismo e inversión inmobiliaria en México. 🏝️🏢\n\n📲 Más info: 56 1858 7276 / 32 2596 0129""",
        "imagen": r"C:\Users\4to CREATIVO\Desktop\WhatsAutoA\Images\summita.png"
    }
]

# %%
# Asignar un mensaje aleatorio a cada número
asignaciones = []
random.seed(42)  # Para reproducibilidad

for numero in numeros:
    asignacion = random.choice(mensajes)
    asignaciones.append({
        "Movil": numero,
        "Mensaje": asignacion["mensaje"].replace("\n", "\n"),
        "Imagen": asignacion["imagen"]
    })

# Convertir a DataFrame de pandas
df = pd.DataFrame(asignaciones)
df
# Out:
#          Movil                                            Mensaje  \
# 0   3231134945  🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perd...
# 1   3231179415  🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perd...
# 2   3231210929  🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perd...
# 3   3231212470  🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perd...
# 4   3231215393  🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perd...
# ..         ...                                                ...
# 70  3521104383  🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perd...
# 71  3521128086  🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perd...
# 72  3521205475  🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perd...
# 73  3531001517  🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perd...
# 74  3531008840  🎟️ ¡ENTRADA GRATIS! 🎟️\n\n🚀 ¡No te puedes perd...
#
#                                                Imagen
# 0   C:\Users\4to CREATIVO\Desktop\WhatsAutoA\Image...
# 1   C:\Users\4to CREATIVO\Desktop\WhatsAutoA\Image...
# ...

# %% [markdown]
# ### Exportar

# %%
# Exportar a un archivo Excel
df.to_csv("negocios_A.csv", index=False)
